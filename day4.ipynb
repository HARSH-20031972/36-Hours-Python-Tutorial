# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSH-20031972/36-Hours-Python-Tutorial/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
user_input=input("Enter the Character=")
for char in user_input:
  if char>='1' and char<='9':
    count+=1
print(count)
# Out:
# Enter the Character=rah23ul
# 2

# %%
def fun(st):
  count=0
  for i in st:
    if i>='0' and i<='9':
      count=count+1
  return count

# %%
st=input()
print(fun(st))
# Out:
# rah23l
# 2

# %%
user_input_str = input("Enter the rating=")
try
  user_rating = int(user_input_str)
  if user_rating >= 30 and user_rating <= 50:
    print("Average")
  elif user_rating >= 51 and user_rating <= 60:
    print("Good")
  elif user_rating >= 61 and user_rating <= 80:
    print("Excellent")
  elif user_rating >= 81 and user_rating <= 100:
    print("Outstanding")
  else:
    print("Not applicable")
except ValueError:
  print("Invalid input. Please enter a numerical rating.")
# Out:
# Enter the rating=77
# Excellent

# %%
def fun(n):
  if(n>=30 and n<=50):
    print("Average")
  elif(n>=51 and n<=60):
    print("Good")
  elif(n>=61 and n<=80):
    print("Excellent")
  elif(n>=81 and n<=100):
    print("Outstanding")
  else:
    print("Not applicable")

# %%
n=int(input())
fun(n)
# Out:
# 77
# Excellent

# %%
n=input("Enter the number=")
output=""
for i in range(1,len(n),2):
  odd=int(n[i])
  odd=odd**2
  output=output+str(odd)
print(output[:4])
# Out:
# Enter the number=7654321
# 3616

# %%
def excludeddigit(num,n):
  count=0
  while(num):
    digit=num%10
    num=num//10
    if(digit!=n):
      count+=1
  return count

# %%
num=int(input())
n=int(input())
print(excludeddigit(num,n))
# Out:
# 66655
# 4
# 5

# %%
input_str=input()
final_str=""
ele_list=input_str.split(",")
for ele in ele_list:
    sin_list=ele.split(".")
    name=sin_list[0]
    number=sin_list[1]
    Max=0
    for digit in number:
      if(int(digit)<len(name)):
        if(Max<int(digit)):
          Max=int(digit)
    if(Max==0):
      pass
    else:
      final_str+=name[Max-1]
    print(final_str)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7095/3976093657.py in <cell line: 0>()
# ----> 1 input_str=input()
#       2 final_str=""
#       3 ele_list=input_str.split(",")
#       4 for ele in ele_list:
#       5     sin_list=ele.split(".")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
def fun(n,a):
  minimum=min(a)
  maximum=max(a)
  return maximum+minimum

# %%
n=int(input())
a=list(map(int,input().split()))
print(fun(n,a))
# Out:
# 4
# 1 2 3 -4
# -1

# %%
def reversestring(s):
  char_list=list(s)
  left=0
  right=0
  len(char_list)-1
  for char in range(len(char_list)):
    if not char_list[char].isalpha():
      right+=1
    elif char_list[char].isalpha():
      while not char_list[right].isalpha():
        right+=1
      temp=char_list[char]
      char_list[char]=char_list[right]
      char_list[right]=temp

# %%
def reverse_string(text):
  li=[]
  for ch in text:
    # Assuming the intent was to build a reversed string using the list
    li.insert(0, ch) # Inserts each character at the beginning to reverse order
  return "".join(li) # Joins the characters to form the reversed string

# %%
import re
s=input()
x=re.findall("[a-zA-Z]")
x.reverse()
for i in range(len(s)):
  if not[s[i].isalpha]

# %%
# Expected input: a comma-separated string of numbers, e.g., '1,2,3,4,5,6,7,8'
user_input_str = input()
x_str_list = user_input_str.split(',')

# Convert string list to integer list
try:
    x = [int(item.strip()) for item in x_str_list] # strip whitespace and convert to int
except ValueError:
    print("Error: Please ensure all inputs are valid integers.")
    exit()

number1=0
number2_sum=0 # Changed to sum, initialized to 0 to accumulate integer sum

# Find indices of 4 and 7
try:
    index_4 = x.index(4)
    index_7 = x.index(7)
except ValueError as e:
    print(f"Error: {e}. Both numbers 4 and 7 must be present in the input.")
    exit()

# Ensure 7 always comes after 4 as per problem description (from previous context)
if index_4 >= index_7:
    print("Error: As per the problem statement, 7 must always come after 4.")
    exit()

# Calculate number1: sum of numbers not between 4 and 7 (inclusive)
for i in range(len(x)):
  if i < index_4 or i > index_7:
    number1 += x[i]

# Calculate number2_sum: sum of numbers from 4 to 7 (inclusive)
for i in range(index_4, index_7 + 1):
  number2_sum += x[i] # Summing integers

print(number1 + number2_sum) # Now adding two integers
# Out:
# "123456789"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21194/1926611508.py in <cell line: 0>()
#       3 number2=""
#       4 for i in range(0,len(x)):
# ----> 5   if(i<x.index("4") or i>x.index("7")):
#       6     number1+=int(x[i])
#       7 for i in range(x.index("4"),x.index("7")+1):
#
# ValueError: '4' is not in list

# %%
user_input_str = input()
x_str_list = user_input_str.split(',')
try:
    x = [int(item.strip()) for item in x_str_list]
except ValueError:
    print("Error: Please ensure all inputs are valid integers.")
    exit()
number1=0
number2=0
try:
    index_4=x.index(4)
    index_7=x.index(7)
except ValueError as e:
    print(f"Error: {e}. Both numbers 4 and 7 must be present in the input.")
    exit()
if index_4>=index_7:
    print("Error: As per the problem statement, 7 must always come after 4.")
    exit()
for i in range(len(x)):
  if i<index_4 or i > index_7:
    number1+=x[i]
for i in range(index_4,index_7+1):
  number2+=x[i]
# Out:
# "1, 2, 3, 4, 5, 6, 7, 8, 9"
# Error: Please ensure all inputs are valid integers.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_30446/1510547120.py in <cell line: 0>()
#       9 number2=0
#      10 try:
# ---> 11     index_4=x.index(4)
#      12     index_7=x.index(7)
#      13 except ValueError as e:
#
# NameError: name 'x' is not defined

# %%
x=input().split(',')
for i in x:
  s,n=i.split(":")
  sum=0
  result=""
  for digit in n:
    sum+=int(digit)**2
  if sum%2==0:
    sub=s[len(s)-2.len(s)]
    result=sub+s[0:len(s)-2]
  else:
    sub=s[len(s)-1]
    result=s[0:len(s)-1]+sub
  print(result,end=' ')
# Out:
#   File "/tmp/ipykernel_33678/3454609325.py", line 9
#     sub=s[len(s)-2.len(s)]
#                   ^
# SyntaxError: invalid decimal literal

# %%
def max_subarray(arr):
  arr=list(map(int,input().split()))
  l=0
  curr_sum=arr[0]
  max_sum=arr[0]
  start=0
  end=0
  temp_start=0
  # deciding to start a new subarray or continue with old Kadane's algo
  for i in range(1,len(arr)):
    if arr[i]>curr_sum+arr[i]:
      curr_sum=arr[i]
      temp_start=i
    else:
      curr_sum+=arr[i]
    if curr_sum>max_sum:
      max_sum=curr_sum
      start=temp_start
      end=i
  print(max_sum)
  print(arr[start:end+1])

# %%
def max_subarray(arr):
  k=len(arr)
  arr=list(map(int,input().split()))
  l=0
  curr_sum=arr[0]
  max_sum=arr[0]
  start=0
  end=k
  temp_start=0
  for i in range(1,len(arr)):
    if arr[i]>curr_sum+arr[i]:
      curr_sum=arr[i]
      temp_start=i
    else:
      curr_sum+=arr[i]
    if curr_sum>max_sum:
      max_sum=curr_sum
      start=temp_start
      end=i
  print(max_sum)
  print(arr[start:end+1])

# %%
def max_sub_arr_with_indices(arr,k):
  if not arr or k<=0 or k>len(arr):
    return (0,-1)
    window_sum=sum(arr[:k])
    max_sum=window_sum
    start_index=0
    for i in range(k,len(arr)):
      window_sum=window_sum-arr[i-k]+arr[i]
      if max_sum==window_sum:
        start_index=i-k+1
        return(max_sum,start_index)

# %%
#Dynamic Programming
def fibbonaci(n):
  #print function call with indentation
  if n<=2:
    return 1
  return fibbonaci(n-1)+fibbonaci(n-2)

# %%
fibbonaci(6)
# Out:
# 8

# %%
import inspect
def stack_depth():
  return len(inspect.getouterframes(inspect.currentframe()))-1
def fibbonaci(n):
  print("{indent} Fibbonaci({n}) called".format(indent=" "*stack_depth(),n=n))
  if n<=2:
    return 1
  return fibbonaci(n-1)+fibbonaci(n-2)
print("Result ",fibbonaci(6))
# Out:
#                         Fibbonaci(6) called
#                          Fibbonaci(5) called
#                           Fibbonaci(4) called
#                            Fibbonaci(3) called
#                             Fibbonaci(2) called
#                             Fibbonaci(1) called
#                            Fibbonaci(2) called
#                           Fibbonaci(3) called
#                            Fibbonaci(2) called
#                            Fibbonaci(1) called
#                          Fibbonaci(4) called
#                           Fibbonaci(3) called
#                            Fibbonaci(2) called
#                            Fibbonaci(1) called
#                           Fibbonaci(2) called
# Result  8

# %%
fibbonaci_cache=()
def fibbonaci(n):
  if n<2:
    return 1
  if n not in fibbonaci_cache:
    fibbonaci_cache[n]=fibbonaci(n-1)+fibbonaci(n-2)
  return fibbonaci_cache(n)

# %%
def fibbonaci(n):
  series[1,1]
  while len(series)<n:
    next_value=series[-1]+series[-2]
    series.append(next_value)
    print(series)
  return series[-1]
