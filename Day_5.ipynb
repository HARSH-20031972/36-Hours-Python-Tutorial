# %% [markdown]
# <a href="https://colab.research.google.com/github/HARSH-20031972/36-Hours-Python-Tutorial/blob/main/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
arr=[]
n=len(arr)
for i in range(n):
  m=int(input("Enter the numbers ="))
  for j in range(arr[i]):
    if j*j*j==m:
      count+=1
    else:
      count=0
  print(count)

# %%
def dimension_is(t):
  if t==1: # 1 is a perfect cube (1*1*1=1)
      return 1
  if t<=0: # 0 is a perfect cube (0*0*0=0), negative numbers are not usually considered
      return 0
  i=1
  result=0
  while i*i*i <= t: # Loop while cube is less than or equal to t
    if i*i*i==t:
      result=1
      break
    i=i+1
  return result
n=int(input("Enter The Number "))
a=list(map(int,input().strip().split()))
perfect_cube=0
for element in a:
  if dimension_is(element)==1:
    perfect_cube+=1
print(perfect_cube)
# Out:
# Enter The Number 8
# 2 4 6 8 27 64
# 3

# %%
def assignment(arr,n):
  t=int(input("Test Case="))
  t=len(arr)
  n=int(input("Enter Key Value="))
  sum=0
  for i in range(t-1):
    arr[i]=int(input("Enter Element="))
    sum+=(arr[i]%n)
  print(sum)

# %%
def mode(a,n,value):
  sum=0
  for i in range(0,n):
    sum=sum+(a[i]%value)
  return sum

# %%
n=int(input("Enter the number="))
value=int(input())
a=list(map(int,input().split()))
print(mode(a,len(a),value))
# Out:
# Enter the number=5
# 4
# 13 16 33 45
# 3

# %%
def appID(num):
  sum=0
  for i in range(num==0):
    num%=10
    sum+=num
    num/=10
  print(sum)

# %%
#Solution
def fun(n):
  s=0
  while n!=0 or s>26:
    if s>26:
      n=s
      s=0
    rem=n%10
    s+=rem
    n//=10
  return char(s+64)

# %%
def appID(num):
  x=num
  sum=0
  for i in range(num==0):
    num%=10
    sum=num*10+sum
    num/=10
  print(num-sum)

# %%
def reverse(n):
  rev=0
  temp=n
  rem=0
  while(n):
    rem=n%10
    rev=rev*10+rem
    n//=10
  return(temp-rev)

# %%
def count_distribution(stock):
  count=0
  while stock>0:
    if stock%2==0:
      stock//=2
    else:
      stock-=1
      count+=1
  print(count_distribution(6))

# %%
def fun(n):
  count=0
  while n!=0:
    if n%2==0:
      n/=2
      count=count+1
    else:
      n-=1
      count+=1
  return count

# %%
n=int(int(input("Enter the number=")))
print(fun(n))
# Out:
# Enter the number=20
# 6
